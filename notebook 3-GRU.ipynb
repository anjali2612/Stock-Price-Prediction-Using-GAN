# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from numpy import *
from math import sqrt
from pandas import *
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Embedding, TimeDistributed, LeakyReLU
from tensorflow.keras.layers import GRU, LSTM
from tensorflow.keras.optimizers import Adam
from matplotlib import pyplot
from pickle import load

# %% [markdown]
# ### load data

# %%
# Load data
X_train = np.load("X_train.npy", allow_pickle=True)
y_train = np.load("y_train.npy", allow_pickle=True)
X_test = np.load("X_test.npy", allow_pickle=True)
y_test = np.load("y_test.npy", allow_pickle=True)
yc_train = np.load("yc_train.npy", allow_pickle=True)
yc_test = np.load("yc_test.npy", allow_pickle=True)

# %% [markdown]
#  EPOCH-indicates the number of passes of the entire training dataset the machine learning algorithm has completed.

# %%
# Parameters
LR = 0.0001
BATCH_SIZE = 128
N_EPOCH = 50

input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = y_train.shape[1]

# %% [markdown]
# ### 1. GRU model:
# **Gated Recurrent Unit (GRU)** -
# - GRUs are very similar to Long Short Term Memory(LSTM). Just like LSTM, GRU uses gates to control the flow of information.
# - GRU have two gates the update gate and reset gate for filtering out what information should remain and what should be disposed of.

# %%
def basic_GRU(input_dim, output_dim, feature_size) -> tf.keras.models.Model:
    model = Sequential()
    model.add(GRU(units=128, return_sequences = True, input_shape=(input_dim, feature_size)))  # 256, return_sequences = True
    # model.add(GRU(units=256, recurrent_dropout = 0.2)) #, return_sequences = True
    model.add(GRU(units=64, input_shape=(input_dim, feature_size)))
    #model.add(Dense(128))
    model.add(Dense(32))
    # model.add(Dense(32))
    model.add(Dense(units=output_dim))
    model.compile(optimizer=Adam(lr=LR), loss='mse')
    history = model.fit(X_train, y_train, epochs=N_EPOCH, batch_size=BATCH_SIZE, validation_data=(X_test, y_test),
                        verbose=2, shuffle=False)

    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()

    return model

# %%
model = basic_GRU(input_dim, output_dim, feature_size)
print(model.summary())
model.save('GRU_30to3.h5')

yhat = model.predict(X_test, verbose=0)
# print(yhat)

rmse = sqrt(mean_squared_error(y_test, yhat))
print(rmse)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 14/14 - 15s - loss: 0.4275 - val_loss: 0.0594 - 15s/epoch - 1s/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0222 - val_loss: 0.0324 - 360ms/epoch - 26ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0226 - val_loss: 0.0367 - 309ms/epoch - 22ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0458 - 410ms/epoch - 29ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0486 - 301ms/epoch - 21ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0053 - val_loss: 0.0483 - 358ms/epoch - 26ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0047 - val_loss: 0.0481 - 333ms/epoch - 24ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.0041 - val_loss: 0.0470 - 363ms/epoch - 26ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0036 - val_loss: 0.0449 - 342ms/epoch - 24ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0032 - val_loss: 0.0428 - 341ms/epoch - 24ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0028 - val_loss: 0.0407 - 335ms/epoch - 24ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0024 - val_loss: 0.0387 - 358ms/epoch - 26ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0021 - val_loss: 0.0369 - 357ms/epoch - 25ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0019 - val_loss: 0.0352 - 358ms/epoch - 26ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0016 - val_loss: 0.0336 - 362ms/epoch - 26ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0322 - 358ms/epoch - 26ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 0.0012 - val_loss: 0.0309 - 373ms/epoch - 27ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 0.0011 - val_loss: 0.0297 - 331ms/epoch - 24ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 9.6756e-04 - val_loss: 0.0286 - 323ms/epoch - 23ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 8.6199e-04 - val_loss: 0.0276 - 354ms/epoch - 25ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 7.7367e-04 - val_loss: 0.0267 - 316ms/epoch - 23ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 7.0017e-04 - val_loss: 0.0258 - 292ms/epoch - 21ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 6.3934e-04 - val_loss: 0.0251 - 330ms/epoch - 24ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 5.8922e-04 - val_loss: 0.0244 - 334ms/epoch - 24ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 5.4806e-04 - val_loss: 0.0238 - 330ms/epoch - 24ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 5.1433e-04 - val_loss: 0.0233 - 350ms/epoch - 25ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 4.8671e-04 - val_loss: 0.0228 - 337ms/epoch - 24ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 4.6406e-04 - val_loss: 0.0223 - 280ms/epoch - 20ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 4.4542e-04 - val_loss: 0.0219 - 305ms/epoch - 22ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 4.2999e-04 - val_loss: 0.0216 - 339ms/epoch - 24ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 4.1712e-04 - val_loss: 0.0212 - 303ms/epoch - 22ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 4.0628e-04 - val_loss: 0.0209 - 315ms/epoch - 22ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 3.9703e-04 - val_loss: 0.0206 - 349ms/epoch - 25ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 3.8904e-04 - val_loss: 0.0204 - 287ms/epoch - 20ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 3.8205e-04 - val_loss: 0.0201 - 317ms/epoch - 23ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 3.7583e-04 - val_loss: 0.0199 - 339ms/epoch - 24ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 3.7024e-04 - val_loss: 0.0197 - 295ms/epoch - 21ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 3.6515e-04 - val_loss: 0.0195 - 346ms/epoch - 25ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 3.6047e-04 - val_loss: 0.0193 - 351ms/epoch - 25ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 3.5611e-04 - val_loss: 0.0192 - 301ms/epoch - 22ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 3.5203e-04 - val_loss: 0.0190 - 350ms/epoch - 25ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 3.4817e-04 - val_loss: 0.0188 - 338ms/epoch - 24ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 3.4451e-04 - val_loss: 0.0187 - 318ms/epoch - 23ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 3.4101e-04 - val_loss: 0.0186 - 312ms/epoch - 22ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 3.3765e-04 - val_loss: 0.0184 - 374ms/epoch - 27ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 3.3441e-04 - val_loss: 0.0183 - 310ms/epoch - 22ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 3.3128e-04 - val_loss: 0.0182 - 343ms/epoch - 24ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 3.2825e-04 - val_loss: 0.0180 - 338ms/epoch - 24ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 3.2530e-04 - val_loss: 0.0179 - 310ms/epoch - 22ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 3.2242e-04 - val_loss: 0.0178 - 344ms/epoch - 25ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 3, 128)            63744
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,105
# Trainable params: 103,105
# Non-trainable params: 0
# _________________________________________________________________
# None
# 0.13344073808310875

# %% [markdown]
# ### train data

# %%
def plot_traindataset_result(X_train, y_train):
    train_yhat = model.predict(X_train, verbose=0)

    y_scaler = load(open('y_scaler.pkl', 'rb')) #convert python object to the byte code
    train_predict_index = np.load("index_train.npy", allow_pickle=True) #file save in NumPy file format in array form.

    rescaled_real_y = y_scaler.inverse_transform(y_train)
    rescaled_predicted_y = y_scaler.inverse_transform(train_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=train_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=train_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Train", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    For_MSE = pd.concat([predicted, real], axis=1)
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Train RMSE -- ', RMSE)

    return RMSE

# %% [markdown]
# ### Test data

# %%
# %% --------------------------------------- Plot the result  -----------------------------------------------------------------
def plot_testdataset_result(X_test, y_test):

    test_yhat = model.predict(X_test, verbose=0)
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    test_predict_index = np.load("index_test.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    Input_Before = '2020-01-01'
    predict_result = predict_result.loc[predict_result.index < Input_Before]
    real_price = real_price.loc[real_price.index < Input_Before]

    print(predict_result.tail(10))

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Test RMSE -- ', RMSE)

    return RMSE

# %%
def plot_testdataset_with_result(X_test, y_test):


    test_yhat = model.predict(X_test, 1, verbose=0)

    y_scaler = load(open('y_scaler.pkl', 'rb'))
    test_predict_index = np.load("yc_train.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing with 2020", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Test RMSE with 2020 -- ', RMSE)

    return RMSE

# %% [markdown]
# **Root-mean-square deviation**

# %%
train_RMSE = plot_traindataset_result(X_train, y_train)

# %%
test_RMSE = plot_testdataset_result(X_test, y_test)
print("----- Test_RMSE_LSTM -----", test_RMSE)
# Out:
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-17              NaN              NaN              NaN
# 2019-12-18              NaN              NaN              NaN
# 2019-12-19              NaN              NaN              NaN
# 2019-12-20              NaN              NaN              NaN
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
# 2019-12-31              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-17              NaN              NaN              NaN
# 2019-12-18              NaN              NaN              NaN
# 2019-12-19              NaN              NaN              NaN
# 2019-12-20              NaN              NaN              NaN
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
# 2019-12-31              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-17              NaN              NaN              NaN
# 2019-12-18              NaN              NaN              NaN
# 2019-12-19              NaN              NaN              NaN
# 2019-12-20              NaN              NaN              NaN
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
# 2019-12-31              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2019-12-17              NaN  ...              NaN              NaN
# 2019-12-18              NaN  ...              NaN              NaN
# 2019-12-19              NaN  ...              NaN              NaN
# 2019-12-20              NaN  ...              NaN              NaN
# 2019-12-23              NaN  ...              NaN              NaN
# 2019-12-24              NaN  ...              NaN              NaN
# 2019-12-26              NaN  ...              NaN              NaN
# 2019-12-27              NaN  ...              NaN              NaN
# 2019-12-30              NaN  ...              NaN              NaN
# 2019-12-31              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-17              NaN              NaN              NaN
# 2019-12-18              NaN              NaN              NaN
# 2019-12-19              NaN              NaN              NaN
# 2019-12-20              NaN              NaN              NaN
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
# 2019-12-31              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-17              NaN              NaN              NaN
# 2019-12-18              NaN              NaN              NaN
# 2019-12-19              NaN              NaN              NaN
# 2019-12-20              NaN              NaN              NaN
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
# 2019-12-31              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2019-12-17              NaN       61.587509
# 2019-12-18              NaN       61.769962
# 2019-12-19              NaN       61.995708
# 2019-12-20              NaN       62.120716
# 2019-12-23              NaN       62.530735
# 2019-12-24              NaN       62.764099
# 2019-12-26              NaN       62.742359
# 2019-12-27              NaN       62.735126
# 2019-12-30              NaN       63.128651
# 2019-12-31              NaN       63.325996
#
# [10 rows x 749 columns]
# ----- Test_RMSE_LSTM ----- 2.554107539438241
